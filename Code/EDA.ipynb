# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
df = pd.read_csv('../data/all_clean.csv')
df
# Out:
#       Unnamed: 0                                               text  \
# 0              0  new semest start corpor financ amp valuat clas...
# 1              1  googl valuabl appl depend valu measur firm vs ...
# 2              2  fall number valuat class start sept number wel...
# 3              3  assum tesla grow audi like revenu number b amp...
# 4              4  twitter snumber valu compani bargain numberb f...
# ...          ...                                                ...
# 6701        6701  yield german govern bond reaction news govern ...
# 6702        6702  fed fund go number number%+ stop peopl buy num...
# 6703        6703  wonder spend day lauderinstitut wharton penn t...
# 6704        6704  need say european govern invest infrastructur ...
# 6705        6705  birth year man olymp basketbal team head coach...
#
#       sp500_mean_label  sp500_last_label  usdx_mean_label  usdx_last_label
# 0                    1               1.0                1              1.0
# ...

# %%
def label_hist_plot(df, columns):
    ax = sns.countplot(data = df, x=columns)
    ax.set_xticklabels(["Down",'Up'])
    ax.set(ylabel='Count of label')
    plt.show()
    # plt.legend(title='SP 500 Mean', labels=["Up",'Down'])
label_hist_plot(df,df.sp500_mean_label)
label_hist_plot(df,df.sp500_last_label)
label_hist_plot(df,df.usdx_mean_label)
label_hist_plot(df,df.usdx_last_label)

# %%
# Wordcloud to display words frequency after cleaning data
from wordcloud import WordCloud, STOPWORDS
text = " ".join(i for i in df.text)
STOPWORDS.update(['t', 'co', 'tweet', 'amp'])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords = stopwords, collocations=False, width = 800, height = 400, background_color="white").generate(text)
plt.figure(figsize=(10,5), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
