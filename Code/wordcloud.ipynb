# %%
import pandas as pd

# %%
data = pd.read_csv("../Data/all_clean.csv")
data
# Out:
#       Unnamed: 0                                               text  \
# 0              0  new semester start corporate finance valuation...
# 1              1  google valuable apple depend value measure fir...
# 2              2  fall valuation class start sept welcome websit...
# 3              3  assume tesla grow audi like revenue b porsche ...
# 4              4  twitter s value company bargain b fair deal b ...
# ...          ...                                                ...
# 6657        6657  yield german government bond reaction news gov...
# 6658        6658  fed funds go + stop people buy foot animatroni...
# 6659        6659  wonderful spend day lauderinstitute wharton pe...
# 6660        6660  need say european government invest infrastruc...
# 6661        6661  birth year man olympics basketball team head c...
#
#       sp500_mean_label  sp500_last_label  usdx_mean_label  usdx_last_label
# 0                    1               1.0                1              1.0
# 1                    0               1.0                0              1.0
# 2                    0               0.0                0              0.0
# 3                    1               1.0                1              1.0
# 4                    0               0.0                0              0.0
# ...                ...               ...              ...              ...
# 6657                 0               0.0                0              0.0
# 6658                 0               0.0                0              0.0
# 6659                 0               0.0                0              0.0
# 6660                 0               0.0                0              0.0
# 6661                 0               0.0                0              0.0
#
# [6662 rows x 6 columns]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

words = " "
stopwords = list(STOPWORDS) + ["t","co", "https", "number", "email"]

for string in data.text:
    tokens = string.split()

    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    tokens = set(tokens)
    words += " ".join(tokens)+ " "

wordcloud = WordCloud(width = 1600, height = 800,
            background_color ="white",
            stopwords = stopwords,
            min_font_size = 15).generate(words)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig('wordcloud.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#       2 import matplotlib.pyplot as plt
#       4 words = " "
#
# ModuleNotFoundError: No module named 'wordcloud'
